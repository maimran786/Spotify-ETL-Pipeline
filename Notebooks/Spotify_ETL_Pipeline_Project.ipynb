# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="ef91acfcb1ec4b349025350fde357b09", client_secret="8ef18e1879a54cde91cf98d8453fed8b")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/4UrJI5NiSOrYzwkqOTbLTW"

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
playlist_URI
# Out:
# '4UrJI5NiSOrYzwkqOTbLTW'

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/4UrJI5NiSOrYzwkqOTbLTW/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2025-01-24T12:16:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/elysianrecords'},
#     'href': 'https://api.spotify.com/v1/users/elysianrecords',
#     'id': 'elysianrecords',
#     'type': 'user',
#     'uri': 'spotify:user:elysianrecords'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
# ...

# %%
data['items']
# Out:
# [{'added_at': '2025-01-24T12:16:27Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/elysianrecords'},
#    'href': 'https://api.spotify.com/v1/users/elysianrecords',
#    'id': 'elysianrecords',
#    'type': 'user',
#    'uri': 'spotify:user:elysianrecords'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '7pNCyGj0ZSbBUSHKD7PKIh'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Paka Poka Funk'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2025-01-24'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 4

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/7pNCyGj0ZSbBUSHKD7PKIh'

# %%
album_list=[]
for row in data['items']:
    album_id=row['track']['album']['id']
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_url=row['track']['album']['external_urls']['spotify']
    album_elements={'album_id':album_id,'name':album_name,'release_date':album_release_date,
                   'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_elements)
album_list
# Out:
# [{'album_id': '7pNCyGj0ZSbBUSHKD7PKIh',
#   'name': 'Paka Poka Funk',
#   'release_date': '2025-01-24',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/7pNCyGj0ZSbBUSHKD7PKIh'},
#  {'album_id': '3ra1kh1AmwAFm1jg9dwONE',
#   'name': 'JOGO DE TOLOS',
#   'release_date': '2024-09-13',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/3ra1kh1AmwAFm1jg9dwONE'},
#  {'album_id': '5A4NgW1yPi2wdNMTCpljWB',
#   'name': 'VAPO SOCA',
#   'release_date': '2024-12-06',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/5A4NgW1yPi2wdNMTCpljWB'},
#  {'album_id': '06a7H7nusNMvM7yL8m3fy1',
#   'name': 'AURA',
#   'release_date': '2024-07-12',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/06a7H7nusNMvM7yL8m3fy1'},
#  {'album_id': '0npGPBqY9AtD8NqFSLMF5P',
#   'name': 'TOMA TOMA',
#   'release_date': '2024-11-08',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/0npGPBqY9AtD8NqFSLMF5P'},
# ...

# %%
data['items'][0]['track']['artists'][0]['id']
# Out:
# '30vnw2IDoHflDzAn9DpqLf'

# %%
artist_list=[]
for row in data['items']:
   for key, value in row.items():
       if key=='track':
           for artists in value['artists']:
               artist_dict={'artist_id':artists['id'],'artist_name':artists['name'],'external_url':artists['href']}
               artist_list.append(artist_dict)
artist_list
# Out:
# [{'artist_id': '2KftmGt9sk1yLjsAoloC3M',
#   'artist_name': 'Zucchero',
#   'external_url': 'https://api.spotify.com/v1/artists/2KftmGt9sk1yLjsAoloC3M'},
#  {'artist_id': '2KftmGt9sk1yLjsAoloC3M',
#   'artist_name': 'Zucchero',
#   'external_url': 'https://api.spotify.com/v1/artists/2KftmGt9sk1yLjsAoloC3M'},
#  {'artist_id': '2KftmGt9sk1yLjsAoloC3M',
#   'artist_name': 'Zucchero',
#   'external_url': 'https://api.spotify.com/v1/artists/2KftmGt9sk1yLjsAoloC3M'},
#  {'artist_id': '2KftmGt9sk1yLjsAoloC3M',
#   'artist_name': 'Zucchero',
#   'external_url': 'https://api.spotify.com/v1/artists/2KftmGt9sk1yLjsAoloC3M'},
#  {'artist_id': '2KftmGt9sk1yLjsAoloC3M',
#   'artist_name': 'Zucchero',
#   'external_url': 'https://api.spotify.com/v1/artists/2KftmGt9sk1yLjsAoloC3M'},
#  {'artist_id': '2KftmGt9sk1yLjsAoloC3M',
#   'artist_name': 'Zucchero',
#   'external_url': 'https://api.spotify.com/v1/artists/2KftmGt9sk1yLjsAoloC3M'},
#  {'artist_id': '2KftmGt9sk1yLjsAoloC3M',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)
song_list
# Out:
# [{'song_id': '5klahCCv1LjPyDQp6VpQ9R',
#   'song_name': 'Paka Poka Funk - Slowed',
#   'duration_ms': 143076,
#   'url': 'https://open.spotify.com/track/5klahCCv1LjPyDQp6VpQ9R',
#   'popularity': 21,
#   'song_added': '2025-01-24T12:16:27Z',
#   'album_id': '7pNCyGj0ZSbBUSHKD7PKIh',
#   'artist_id': '30vnw2IDoHflDzAn9DpqLf'},
#  {'song_id': '5Vuq8CP31cpEEq5zNJCjUN',
#   'song_name': 'JOGO DE TOLOS',
#   'duration_ms': 70400,
#   'url': 'https://open.spotify.com/track/5Vuq8CP31cpEEq5zNJCjUN',
#   'popularity': 74,
#   'song_added': '2024-12-05T22:25:06Z',
#   'album_id': '3ra1kh1AmwAFm1jg9dwONE',
#   'artist_id': '5dDNNq04RjKXFOADdHd6VX'},
#  {'song_id': '4csIFgamqDcSFzCjKycIY3',
#   'song_name': 'VAPO SOCA',
#   'duration_ms': 92307,
#   'url': 'https://open.spotify.com/track/4csIFgamqDcSFzCjKycIY3',
#   'popularity': 34,
#   'song_added': '2024-12-06T00:04:42Z',
#   'album_id': '5A4NgW1yPi2wdNMTCpljWB',
#   'artist_id': '4YeITwoqeIks45gELm488B'},
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id            name release_date  total_tracks  \
# 0  7pNCyGj0ZSbBUSHKD7PKIh  Paka Poka Funk   2025-01-24             4
# 1  3ra1kh1AmwAFm1jg9dwONE   JOGO DE TOLOS   2024-09-13             5
# 2  5A4NgW1yPi2wdNMTCpljWB       VAPO SOCA   2024-12-06             4
# 3  06a7H7nusNMvM7yL8m3fy1            AURA   2024-07-12             3
# 4  0npGPBqY9AtD8NqFSLMF5P       TOMA TOMA   2024-11-08             5
#
#                                                  url
# 0  https://open.spotify.com/album/7pNCyGj0ZSbBUSH...
# 1  https://open.spotify.com/album/3ra1kh1AmwAFm1j...
# 2  https://open.spotify.com/album/5A4NgW1yPi2wdNM...
# 3  https://open.spotify.com/album/06a7H7nusNMvM7y...
# 4  https://open.spotify.com/album/0npGPBqY9AtD8Nq...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63 entries, 0 to 62
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      63 non-null     object
#  1   name          63 non-null     object
#  2   release_date  63 non-null     object
#  3   total_tracks  63 non-null     int64
#  4   url           63 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 3.0+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])
album_df
# Out:
#                   album_id                   name release_date  total_tracks  \
# 0   7pNCyGj0ZSbBUSHKD7PKIh         Paka Poka Funk   2025-01-24             4
# 1   3ra1kh1AmwAFm1jg9dwONE          JOGO DE TOLOS   2024-09-13             5
# 2   5A4NgW1yPi2wdNMTCpljWB              VAPO SOCA   2024-12-06             4
# 3   06a7H7nusNMvM7yL8m3fy1                   AURA   2024-07-12             3
# 4   0npGPBqY9AtD8NqFSLMF5P              TOMA TOMA   2024-11-08             5
# ..                     ...                    ...          ...           ...
# 58  7JslfZtjZ430btdARyxLQ4            PYTHON FUNK   2024-08-23             4
# 59  3apQZbgVql9mHJlp43jk5D          METAMORPHOSIS   2021-11-25             1
# 60  3joHEvqURxvBwrT5JZS3Sn  ✻H+3+ЯД✻7luCJIo0T6...   2024-02-07             1
# 61  0ratr5PQvRjZLZnvjCAmuV           FUNK GALAXIA   2024-12-13             4
# 62  2BgtZq8eLVpq6KAcRPhAAc           FUNK CORACAO   2024-12-27             4
#
# ...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df.head()
# Out:
#                 artist_id artist_name  \
# 0  2KftmGt9sk1yLjsAoloC3M    Zucchero
# 1  2KftmGt9sk1yLjsAoloC3M    Zucchero
# 2  2KftmGt9sk1yLjsAoloC3M    Zucchero
# 3  2KftmGt9sk1yLjsAoloC3M    Zucchero
# 4  2KftmGt9sk1yLjsAoloC3M    Zucchero
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/2KftmGt9sk1...
# 1  https://api.spotify.com/v1/artists/2KftmGt9sk1...
# 2  https://api.spotify.com/v1/artists/2KftmGt9sk1...
# 3  https://api.spotify.com/v1/artists/2KftmGt9sk1...
# 4  https://api.spotify.com/v1/artists/2KftmGt9sk1...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                song_name  duration_ms  \
# 0  5klahCCv1LjPyDQp6VpQ9R  Paka Poka Funk - Slowed       143076
# 1  5Vuq8CP31cpEEq5zNJCjUN            JOGO DE TOLOS        70400
# 2  4csIFgamqDcSFzCjKycIY3                VAPO SOCA        92307
# 3  2TNv2GxMpIO8AyPiD7TLxj                     AURA       115906
# 4  1XjkXxPxexo7KoVUc7rUEZ                TOMA TOMA        90000
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/5klahCCv1LjPyDQ...          21
# 1  https://open.spotify.com/track/5Vuq8CP31cpEEq5...          74
# 2  https://open.spotify.com/track/4csIFgamqDcSFzC...          34
# 3  https://open.spotify.com/track/2TNv2GxMpIO8AyP...          76
# 4  https://open.spotify.com/track/1XjkXxPxexo7KoV...          52
#
#              song_added                album_id               artist_id
# 0  2025-01-24T12:16:27Z  7pNCyGj0ZSbBUSHKD7PKIh  30vnw2IDoHflDzAn9DpqLf
# ...

# %%
artist_df.head()
# Out:
#                 artist_id artist_name  \
# 0  2KftmGt9sk1yLjsAoloC3M    Zucchero
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/2KftmGt9sk1...

# %%
album_df.head()
# Out:
#                  album_id            name release_date  total_tracks  \
# 0  7pNCyGj0ZSbBUSHKD7PKIh  Paka Poka Funk   2025-01-24             4
# 1  3ra1kh1AmwAFm1jg9dwONE   JOGO DE TOLOS   2024-09-13             5
# 2  5A4NgW1yPi2wdNMTCpljWB       VAPO SOCA   2024-12-06             4
# 3  06a7H7nusNMvM7yL8m3fy1            AURA   2024-07-12             3
# 4  0npGPBqY9AtD8NqFSLMF5P       TOMA TOMA   2024-11-08             5
#
#                                                  url
# 0  https://open.spotify.com/album/7pNCyGj0ZSbBUSH...
# 1  https://open.spotify.com/album/3ra1kh1AmwAFm1j...
# 2  https://open.spotify.com/album/5A4NgW1yPi2wdNM...
# 3  https://open.spotify.com/album/06a7H7nusNMvM7y...
# 4  https://open.spotify.com/album/0npGPBqY9AtD8Nq...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      66 non-null     object
#  1   song_name    66 non-null     object
#  2   duration_ms  66 non-null     int64
#  3   url          66 non-null     object
#  4   popularity   66 non-null     int64
#  5   song_added   66 non-null     datetime64[ns, UTC]
#  6   album_id     66 non-null     object
#  7   artist_id    66 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 4.3+ KB

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63 entries, 0 to 62
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      63 non-null     object
#  1   name          63 non-null     object
#  2   release_date  63 non-null     datetime64[ns]
#  3   total_tracks  63 non-null     int64
#  4   url           63 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 3.0+ KB
